# %%
# !pip install gdown

# %%
import gdown

url = 'https://drive.google.com/uc?id=1B8ZQoiiRVSO36gQB8vtZdcLB3Nj7iCNH'

output = 'midv_2020.zip'
gdown.download(url, output)

# %%
# !unzip midv_2020.zip >/dev/null
print('[INFO] The dataset has been unzipped...')

# %%
# !ls

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
cd pytorch-CycleGAN-and-pix2pix

# %%
# !pip install -r requirements.txt

# %%
import wandb
wandb.login()

# %%
# !python train.py --dataroot ../midv_2020 --name midv_2020_pix2pix --model pix2pix --output_nc 1 --netG unet_256 --preprocess none --no_flip --display_id 0 --use_wandb
