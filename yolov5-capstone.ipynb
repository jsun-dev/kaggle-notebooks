# %% [markdown]
# Reference: https://www.kaggle.com/code/ultralytics/yolov5/notebook

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
# !pip install gdown

# %%
import gdown

url = 'https://drive.google.com/uc?id=1X5m233R1pp3feOlz70VSF_yzN0BL7uSn'

output = 'MIDV-2020.zip'
gdown.download(url, output)

# %%
# !unzip MIDV-2020.zip >/dev/null

# %%
# %pip install -q wandb
import wandb
wandb.login()

# %%
# !python train.py --epochs 100 --data data.yaml --weights yolov5s.pt

# %%
# !ls

# %%
# !zip -r out.zip runs

# %% [markdown]
# <a href="./yolov5/out.zip"> Download ZIP folder </a>
